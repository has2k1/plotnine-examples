# %%
from plotnine import ggplot, aes, geom_area, geom_line
from plotnine.data import economics

# %% [markdown]
# ### Shaded Area Under Line

# %%
# Gallery, lines
(
    ggplot(economics, aes(x="date", y="unemploy"))
    + geom_line()
    + geom_area(fill="turquoise", alpha=0.5)
)
